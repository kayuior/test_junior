# %%
import pandas as pd

# %%
posts_df = pd.read_csv('StackOverflow/2016/01/posts.csv.gz', compression='gzip')
posts_df
# Out:
# /var/folders/45/3yd75r710n596zzjptn127qw0000gn/T/ipykernel_6342/1171366832.py:1: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   posts_df = pd.read_csv('StackOverflow/2016/01/posts.csv.gz', compression='gzip')
#                                                     title  answer_count  \
# 0                                                     NaN           NaN
# 1                                                     NaN           NaN
# 2                                                     NaN           NaN
# 3                                                     NaN           NaN
# 4                                                     NaN           NaN
# ...                                                   ...           ...
# 475519  Is there a downside to declaring variables wit...          13.0
# 475520  Check two arguments in Java either both not nu...          13.0
# ...

# %%
users_df = pd.read_csv('StackOverflow/2016/01/users.csv.gz', compression='gzip')
users_df
# Out:
#               id        display_name                creation_date  reputation  \
# 0        2827250  Przemyslaw Kruglej   2013-09-28 22:16:23.28 UTC        7383
# 1        3659052              logger  2014-05-21 03:21:02.987 UTC        1126
# 2         962091           zackdever  2011-09-23 23:20:18.113 UTC        1497
# 3        1112901              Xavier  2011-12-23 05:58:06.577 UTC        2664
# 4         103647       Dmitri Farkov  2009-05-08 16:01:26.863 UTC        7068
# ...          ...                 ...                          ...         ...
# 5021689  2020214             shackra   2013-01-29 02:47:09.32 UTC          31
# 5021690  3250583               Hasan    2014-01-29 20:24:01.4 UTC          36
# 5021691  4936663          Vinay Guru  2015-05-25 11:43:41.987 UTC          36
# 5021692  1347354   Claudio d'Angelis  2012-04-20 19:34:05.723 UTC          36
# 5021693  2118151      Daniel Cazares  2013-02-28 04:40:18.933 UTC          41
#
# ...

# %%
posts_df.shape[0]
# Out:
# 475524

# %%
users_df["creation_datetime"] = pd.to_datetime(users_df["creation_date"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 users_df["creation_date"] = pd.to_datetime(users_df["creation_date"])
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
# ...

# %%
users_df["creation_datetime"]
